# %% [markdown]
# # 02 - Feature Engineering
# Use matminer Magpie descriptors from composition.

# %%
from src.data_loader import load_raw_data
from src.featurization import featurize_compositions
raw = load_raw_data()
X, y = featurize_compositions(raw)
X.head()

# %% [markdown]
# # 04 - Material Discovery
# Predict new candidate compositions.

# %%
from main import generate_candidate_compositions
from src.predict import predict_band_gap_for_compositions
candidates = generate_candidate_compositions()
pred = predict_band_gap_for_compositions(candidates)
pred.head(10)

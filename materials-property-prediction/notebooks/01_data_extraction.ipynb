# %% [markdown]
# # 01 - Data Extraction
# Fetch composition and band gap data from Materials Project.

# %%
from src.data_loader import fetch_materials_data
API_KEY = 'YOUR_MATERIALS_PROJECT_API_KEY'
df = fetch_materials_data(API_KEY, num_materials=1000)
df.head()
